# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ### Frequency Functions

# %%
fdist = FreqDist(sent4) # gives each variable frequency
fdist
# Out:
# FreqDist({'of': 3, 'the': 2, 'Fellow': 1, '-': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
def inc(fdist, sample):
    fdist[sample] += 1
    return fdist

fdist = inc(fdist, '-')
fdist
# Out:
# FreqDist({'-': 9, 'of': 3, 'the': 2, 'Fellow': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
fdist['Fellow'] # gives the count of the word
# Out:
# 1

# %%
fdist.freq('Fellow') # gives the freq of the given word
# Out:
# 0.07142857142857142

# %%
fdist.N()
# Out:
# 14

# %%
fdist.keys()
# Out:
# dict_keys(['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'House', 'Representatives', ':'])

# %%
for sample in fdist:
    print(sample)
# Out:
# of
# -
# the
# Fellow
# Citizens
# Senate
# and
# House
# Representatives
# :

# %%
fdist.max()
# Out:
# 'of'

# %%
fdist.tabulate()
# Out:
#              of               -             the          Fellow        Citizens          Senate             and           House Representatives               :
#               3               2               2               1               1               1               1               1               1               1

# %%
fdist.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
fdist.plot(cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
FreqDist(sent1)
# Out:
# FreqDist({'Call': 1, 'me': 1, 'Ishmael': 1, '.': 1})

# %%
fdist
# Out:
# FreqDist({'of': 3, '-': 2, 'the': 2, 'Fellow': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
fdist2 = FreqDist(sent1)
print(fdist2)
fdist3 = inc(fdist2, 'Call')
fdist3
# Out:
# <FreqDist with 4 samples and 4 outcomes>
# FreqDist({'Call': 2, 'me': 1, 'Ishmael': 1, '.': 1})

# %%
fdist2 < fdist3
# Out:
# False

# %%
sent4
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %% [markdown]
# ### Word comparision Operators

# %%
s = sent4
s
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
for x in s:
    print(f"{x} \t     {x.startswith('S')}")
# Out:
# Fellow 	     False
# - 	     False
# Citizens 	     False
# of 	     False
# the 	     False
# Senate 	     True
# and 	     False
# of 	     False
# the 	     False
# House 	     False
# of 	     False
# Representatives 	     False
# : 	     False

# %%
for x in s:
    print(f"{x} \t     {x.endswith('s')}")
# Out:
# Fellow 	     False
# - 	     False
# Citizens 	     True
# of 	     False
# the 	     False
# Senate 	     False
# and 	     False
# of 	     False
# the 	     False
# House 	     False
# of 	     False
# Representatives 	     True
# : 	     False

# %%
for x in s:
    print('t' in x)
# Out:
# False
# False
# True
# False
# True
# True
# False
# False
# True
# False
# False
# True
# False

# %%
for x in s:
    print(x.islower())
# Out:
# False
# False
# False
# True
# True
# False
# True
# True
# True
# False
# True
# False
# False

# %%
for x in s:
    print(x.isalpha())
# Out:
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False

# %%
for x in s:
    print(x.isupper())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for x in s:
    print(x.isalnum())
# Out:
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False

# %%
for x in s:
    print(x.isdigit())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for x in s:
    print(x.istitle())
# Out:
# True
# False
# True
# False
# False
# True
# False
# False
# False
# True
# False
# True
# False

# %%
sorted([w for w in set(sent7) if not w.islower()])
# Out:
# [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']

# %%
sorted([wd for wd in set(text3) if wd.istitle() and len(wd)>6])
# Out:
# ['Abelmizraim',
#  'Abimael',
#  'Abimelech',
#  'Abraham',
#  'Adullamite',
#  'Aholibamah',
#  'Ahuzzath',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Amalekites',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'Appoint',
#  'Arphaxad',
#  'Arvadite',
#  'Asenath',
#  'Ashkenaz',
#  'Ashteroth',
#  'Asshurim',
#  'Assyria',
#  'Baalhanan',
#  'Bashemath',
#  'Because',
#  'Beerlahairoi',
#  'Beersheba',
#  'Benjamin',
#  'Bethlehem',
#  'Bethuel',
#  'Binding',
#  'Blessed',
#  'Canaanite',
#  'Canaanites',
#  'Canaanitish',
#  'Caphtorim',
#  'Casluhim',
#  'Chaldees',
#  'Chedorlaomer',
#  'Cherubims',
#  'Damascus',
#  'Deborah',
#  'Deliver',
#  'Dinhabah',
#  'Discern',
#  'Dodanim',
#  'Edomites',
#  'Egyptia',
#  'Egyptian',
#  'Egyptians',
#  'Elbethel',
#  'Eliezer',
#  'Eliphaz',
#  'Elishah',
#  'Ellasar',
#  'Elparan',
#  'Enmishpat',
#  'Ephraim',
#  'Ephrath',
#  'Ethiopia',
#  'Euphrat',
#  'Euphrates',
#  'Fifteen',
#  'Forasmuch',
#  'Forgive',
#  'Gentiles',
#  'Gershon',
#  'Girgashites',
#  'Girgasite',
#  'Gomorrah',
#  'Hadoram',
#  'Hamathite',
#  'Havilah',
#  'Hazarmaveth',
#  'Hazezontamar',
#  'Hebrews',
#  'Hiddekel',
#  'Hittite',
#  'Hittites',
#  'Horites',
#  'Ishmael',
#  'Ishmeelites',
#  'Issachar',
#  'Jahleel',
#  'Jahzeel',
#  'Japheth',
#  'Jebusite',
#  'Jebusites',
#  'Jegarsahadutha',
#  'Jehovahjireh',
#  'Jetheth',
#  'Jidlaph',
#  'Jokshan',
#  'Kadmonites',
#  'Karnaim',
#  'Kedemah',
#  'Kenites',
#  'Kenizzites',
#  'Keturah',
#  'Kiriathaim',
#  'Kirjatharba',
#  'Lahairoi',
#  'Lehabim',
#  'Letushim',
#  'Leummim',
#  'Maachah',
#  'Machpelah',
#  'Magdiel',
#  'Mahalaleel',
#  'Mahalath',
#  'Mahanaim',
#  'Malchiel',
#  'Manahath',
#  'Manasseh',
#  'Masrekah',
#  'Mehetabel',
#  'Mehujael',
#  'Melchizedek',
#  'Meshech',
#  'Mesopotamia',
#  'Methusa',
#  'Methusael',
#  'Methuselah',
#  'Mezahab',
#  'Midianites',
#  'Mizraim',
#  'Moabites',
#  'Moreover',
#  'Naphish',
#  'Naphtali',
#  'Naphtuhim',
#  'Nebajoth',
#  'Neither',
#  'Nineveh',
#  'Padanaram',
#  'Pathrusim',
#  'Peradventure',
#  'Perizzit',
#  'Perizzite',
#  'Perizzites',
#  'Pharaoh',
#  'Phichol',
#  'Philistim',
#  'Philistines',
#  'Pildash',
#  'Potiphar',
#  'Potipherah',
#  'Rameses',
#  'Rebekah',
#  'Rehoboth',
#  'Rephaims',
#  'Riphath',
#  'Sabtech',
#  'Shammah',
#  'Shechem',
#  'Sheleph',
#  'Shemeber',
#  'Shillem',
#  'Shimron',
#  'Sojourn',
#  'Succoth',
#  'Tarshish',
#  'Thahash',
#  'Therefore',
#  'Timnath',
#  'Togarmah',
#  'Tubalcain',
#  'Unstable',
#  'Whereas',
#  'Wherefore',
#  'Zaphnathpaaneah',
#  'Zeboiim',
#  'Zebulun',
#  'Zemarite',
#  'Ziphion']

# %%
from nltk.corpus import brown

brown.words(fileids=['cg22'])
# Out:
# ['Does', 'our', 'society', 'have', 'a', 'runaway', ',', ...]
