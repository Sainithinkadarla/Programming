# %%
from nltk.book import *

# %% [markdown]
# ### Frequency Functions

# %%
fdist = FreqDist(sent4) # gives each variable frequency
fdist
# Out:
# FreqDist({'of': 3, 'the': 2, 'Fellow': 1, '-': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
def inc(fdist, sample):
    fdist[sample] += 1
    return fdist

fdist = inc(fdist, 'of')
fdist
# Out:
# FreqDist({'of': 17, 'the': 11, 'Fellow': 1, '-': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
fdist['Fellow'] # gives the count of the word
# Out:
# 1

# %%
fdist.freq('Fellow') # gives the freq of the given word
# Out:
# 0.07692307692307693

# %%
fdist.N()
# Out:
# 13

# %%
fdist.keys()
# Out:
# dict_keys(['Fellow', '-', 'Citizens', 'of', 'the', 'Senate', 'and', 'House', 'Representatives', ':'])

# %%
for sample in fdist:
    print(sample)
# Out:
# of
# the
# Fellow
# -
# Citizens
# Senate
# and
# House
# Representatives
# :

# %%
fdist.max()
# Out:
# 'of'

# %%
fdist.tabulate()
# Out:
#              of             the          Fellow               -        Citizens          Senate             and           House Representatives               :
#               3               2               1               1               1               1               1               1               1               1

# %%
fdist.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
fdist.plot(cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
FreqDist(sent1)
# Out:
# FreqDist({'Call': 1, 'me': 1, 'Ishmael': 1, '.': 1})

# %%
fdist
# Out:
# FreqDist({'of': 17, 'the': 11, 'Fellow': 1, '-': 1, 'Citizens': 1, 'Senate': 1, 'and': 1, 'House': 1, 'Representatives': 1, ':': 1})

# %%
fdist2 = FreqDist(sent1)
print(fdist2)
fdist3 = inc(fdist2, 'Call')
fdist3
# Out:
# <FreqDist with 4 samples and 4 outcomes>
# FreqDist({'Call': 2, 'me': 1, 'Ishmael': 1, '.': 1})

# %%
fdist2 < fdist3
# Out:
# False

# %%
sent4
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %% [markdown]
# ### Word comparision Operators

# %%
s = sent4
s
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':']

# %%
for x in s:
    print(f"{x} \t     {x.startswith('S')}")
# Out:
# Fellow 	     False
# Fellow 	     False
# False
# - 	     False
# - 	     False
# False
# Citizens 	     False
# Citizens 	     True
# False
# of 	     False
# of 	     False
# True
# the 	     False
# the 	     False
# True
# Senate 	     True
# Senate 	     False
# False
# and 	     False
# and 	     False
# True
# of 	     False
# of 	     False
# True
# the 	     False
# the 	     False
# True
# House 	     False
# House 	     False
# False
# of 	     False
# of 	     False
# True
# Representatives 	     False
# Representatives 	     True
# False
# : 	     False
# : 	     False
# False

# %%
for x in s:
    print(f"{x} \t     {x.endswith('s')}")
# Out:
# Fellow 	     False
# - 	     False
# Citizens 	     True
# of 	     False
# the 	     False
# Senate 	     False
# and 	     False
# of 	     False
# the 	     False
# House 	     False
# of 	     False
# Representatives 	     True
# : 	     False

# %%
for x in s:
    print('t' in x)
# Out:
# False
# False
# True
# False
# True
# True
# False
# False
# True
# False
# False
# True
# False

# %%
for x in s:
    print(x.islower())
# Out:
# False
# False
# False
# True
# True
# False
# True
# True
# True
# False
# True
# False
# False

# %%
for x in s:
    print(x.isalpha())
# Out:
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False

# %%
for x in s:
    print(x.isupper())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for x in s:
    print(x.isalnum())
# Out:
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# False

# %%
for x in s:
    print(x.isdigit())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for x in s:
    print(x.istitle())
# Out:
# True
# False
# True
# False
# False
# True
# False
# False
# False
# True
# False
# True
# False
